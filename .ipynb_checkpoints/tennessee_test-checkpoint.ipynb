# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px

from urllib.request import urlopen


codes_df = pd.read_csv('all-geocodes-v2017.csv')
#pop_df = pd.read_csv('co-est2019-alldata.csv', sep=',', encoding='gbk')
tn_fips = 47
tn_codes = codes_df.loc[(codes_df['State Code (FIPS)'] == tn_fips)]
tn_codes = tn_codes[['County Code (FIPS)', 'Area Name (including legal/statistical area description)']].reset_index()
tn_codes.drop('index', axis=1,inplace=True)
tn_codes['County Code (FIPS)'] = tn_codes['County Code (FIPS)'].astype(str)
m = tn_codes['County Code (FIPS)'].str.len().max()
tn_codes['FIPS'] = tn_codes['County Code (FIPS)'].str.rjust(m, fillchar='0')

pop_df = pd.read_csv('co-est2019-cumchg-47.csv')
col_to_rename = pop_df.columns[2]

# %%
pop_df.head()
# Out:
#                     Unnamed: 0 April 1, 2010 Estimates Base July 1, 2019  \
# 0                    Tennessee                    6,346,276    6,829,174
# 1  .Anderson County, Tennessee                       75,082       76,978
# 2   .Bedford County, Tennessee                       45,057       49,713
# 3    .Benton County, Tennessee                       16,491       16,160
# 4   .Bledsoe County, Tennessee                       12,874       15,064
#
#     Number Percent April 1, 2010 Estimates Base.1 July 1, 2019.1 Number.1  \
# 0  482,898     7.6                            (X)            (X)      (X)
# 1    1,896     2.5                             17             18       31
# 2    4,656    10.3                             33             32       18
# 3     -331    -2.0                             76             76       76
# 4    2,190    17.0                             82             77       29
#
#   Percent.1
# 0       (X)
# 1        47
# 2        14
# 3        77
# 4         8

# %%
pop_df.rename(columns={'Unnamed: 0':'County and State', 'April 1, 2010 Estimates Base':'Apr 2010 Pop', col_to_rename:'Jul 2019 Pop', 'Number':'Change in Pop', 'Percent':'Percent Change in Pop', 'April 1, 2010 Estimates Base.1':'Apr 2010 Rank', 'July 1, 2019':'Jul 2019 Rank', 'Number.1':'Change in Rank'}, inplace=True)
pop_df.drop('Percent.1', axis=1, inplace=True)

pop_df['County'] = pop_df['County and State'].str.split(',').str[0]
pop_df['County'] = pop_df['County'].str.replace('.', '')

df = pop_df.merge(tn_codes, how='left', left_on='County', right_on='Area Name (including legal/statistical area description)')
#Give each FIPS code the tn prefix
df['County Code (FIPS)'] = df['County Code (FIPS)'].astype(str)
df['FIPS'] = '47' + df['FIPS']

# %%
df.head()
# Out:
#               County and State Apr 2010 Pop Jul 2019 Rank Change in Pop  \
# 0                    Tennessee    6,346,276     6,829,174       482,898
# 1  .Anderson County, Tennessee       75,082        76,978         1,896
# 2   .Bedford County, Tennessee       45,057        49,713         4,656
# 3    .Benton County, Tennessee       16,491        16,160          -331
# 4   .Bledsoe County, Tennessee       12,874        15,064         2,190
#
#   Percent Change in Pop Apr 2010 Rank July 1, 2019.1 Change in Rank  \
# 0                   7.6           (X)            (X)            (X)
# 1                   2.5            17             18             31
# 2                  10.3            33             32             18
# 3                  -2.0            76             76             76
# 4                  17.0            82             77             29
#
#             County County Code (FIPS)  \
# 0        Tennessee                  0
# 1  Anderson County                  1
# 2   Bedford County                  3
# 3    Benton County                  5
# 4   Bledsoe County                  7
#
#   Area Name (including legal/statistical area description)   FIPS
# 0                                          Tennessee        47000
# 1                                    Anderson County        47001
# 2                                     Bedford County        47003
# 3                                      Benton County        47005
# 4                                     Bledsoe County        47007

# %%
df.write_csv(df)

# %%
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)
    
counties["features"][0]

# %%
rank_fig = px.choropleth(df, geojson=counties, locations='FIPS', color='Jul 2019 Rank',
 scope="usa",
 )

# %%
rank_fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
